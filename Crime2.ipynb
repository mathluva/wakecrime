# %%
import pygeoj
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
import geojson
from pprint import pprint
from shapely.geometry import Point, Polygon
import geopandas as gpd

# %%
import requests
crime2020= requests.get('https://services.arcgis.com/v400IkDOw1ad7Yad/arcgis/rest/services/Daily_Police_Incidents/FeatureServer/0/query?where=1%3D1&outFields=crime_category,crime_description,crime_type,reported_block_address,city_of_incident,city,district,reported_date,reported_year,reported_month,reported_day,reported_hour,reported_dayofwk,latitude,longitude&outSR=4326&f=json')
crime_json=crime2020.json()
pprint(crime_json)
# Out:
# {'features': [{'attributes': {'city': 'RALEIGH',
#                               'city_of_incident': 'RALEIGH',
#                               'crime_category': 'LARCENY',
#                               'crime_description': 'Larceny/Theft from '
#                                                    'Building',
#                               'crime_type': 'CRIMES AGAINST PROPERTY',
#                               'district': 'North',
#                               'latitude': 35.874504496,
#                               'longitude': -78.622925317,
#                               'reported_block_address': '6600 BLOCK FALLS OF '
#                                                         'NEUSE RD',
#                               'reported_date': 1581916500000,
#                               'reported_day': 17,
#                               'reported_dayofwk': 'Monday',
#                               'reported_hour': 0,
#                               'reported_month': 2,
# ...

# %%
df= pd.read_json(crime2020_json)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fa82023abedb> in <module>
# ----> 1 df= pd.read_json(crime2020_json)
#
# NameError: name 'crime2020_json' is not defined

# %%
with open('data.txt', 'w') as outfile:
    json.dump(crime_json, outfile)
